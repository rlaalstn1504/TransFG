# %%
import pandas as pd
import os 
import cv2
import numpy as np
import shutil
import json
import time 
from datetime import timedelta
from tqdm import tqdm
import matplotlib.pyplot as plt
from PIL import Image, ImageFont, ImageDraw
import glob

# %%
label_list = sorted(glob.glob(f'screen/image/*.json')) 
image_list = sorted(glob.glob(f'screen/image/*.jpg'))

# %%
start = time.time()
df_all = pd.DataFrame() 
for _,l in enumerate(label_list):
    with open(l,'r', encoding="UTF-8") as dc:
        data = json.load(dc) 
        df = pd.DataFrame(data['Learning Data Info']['annotations']) 
        df['path'] = data['Learning Data Info']['path']  
        df['json_data_id'] = data['Learning Data Info']['json_data_id']
        df['num'] = _
        df_all = df_all.append(df)

# %%
df_all['json_data_id'] = 'screen/image/'+df_all['json_data_id']

# %%
df_all['json_data_id'] = df_all['json_data_id']+'.jpg'

# %%
def edit_coord(x):
    x[2] = x[0]+x[2] 
    x[3] = x[1]+x[3] 
    x = list(map(lambda x:int(x),x))
    return x

# %%
df_all['coord'] = df_all['coord'].apply(lambda x: edit_coord(x))

# %%
import torch
import torch.distributed as dist

from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms
from apex import amp
from apex.parallel import DistributedDataParallel as DDP
from torch.utils.data import DataLoader, RandomSampler, DistributedSampler, SequentialSampler

from models.modeling import VisionTransformer, CONFIGS
from utils.scheduler import WarmupLinearSchedule, WarmupCosineSchedule
from utils.data_utils import get_loader
from utils.dist_util import get_world_size

from utils.dataset import custom

test_transform=transforms.Compose([transforms.Resize((600, 600), Image.BILINEAR),
                            transforms.CenterCrop((448, 448)),
                            transforms.ToTensor(),
                            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]) 

img_size = 448
smoothing_value = 0.0
pretrained_model = "output/sample_run_checkpoint.bin"
config = CONFIGS["ViT-B_16"]
config.split = 'overlap'
config.slide_step = 12
num_classes = pd.read_csv('train_x.csv')['label'].nunique()
model = VisionTransformer(config, img_size, num_classes, smoothing_value, zero_head=True) 

if pretrained_model is not None:
    pretrained_model = torch.load(pretrained_model, map_location=torch.device('cpu'))['model']
    model.load_state_dict(pretrained_model) 
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# VisionTransformer(
#   (transformer): Transformer(
#     (embeddings): Embeddings(
#       (patch_embeddings): Conv2d(3, 768, kernel_size=(16, 16), stride=(12, 12))
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Encoder(
#       (layer): ModuleList(
#         (0): Block(
#           (attention_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (ffn_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (ffn): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
# ...

# %%
label_dict_train = pd.read_csv('train_x.csv')[['label_','label']].drop_duplicates('label') 
label_dict_val = pd.read_csv('val_x.csv')[['label_','label']].drop_duplicates('label')
label_dict_test = pd.read_csv('test_x.csv')[['label_','label']].drop_duplicates('label') 
label_dict = label_dict_train.append(label_dict_val).append(label_dict_test) 
label_dict = label_dict.drop_duplicates('label').set_index('label').to_dict()['label_']

# %%
for i in range(5):
    print(df_all[df_all['num']==i]['json_data_id'][:1].values[0])
    continue
# Out:
# screen/image/C-220711_07_SR01_01_A0004.jpg
# screen/image/C-220711_07_SR03_01_A0044.jpg
# screen/image/C-220805_06_CR02_01_A0124.jpg
# screen/image/C-220809_13_CR01_01_A0008.jpg
# screen/image/C-220810_09_CR01_02_A0155.jpg

# %%
# cv2 Mat 타입 사용 
picture_num = 4
plt.figure(figsize=(16,12))
img = cv2.imread(df_all[df_all['num']==picture_num]['json_data_id'][0])
position = df_all[df_all['num']==picture_num]['coord']
# cv2 -> PIL 이미지로 변경
color_coverted = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_pil=Image.fromarray(color_coverted)

# PIL 이미지에 한글 입력
draw = ImageDraw.Draw(img_pil)
for i in position: 
    
    x = test_transform(Image.fromarray(np.uint8(img_pil.crop(i))).convert('RGB')).unsqueeze(0) 
    x = x.to(device)
    part_logits = model(x) 
    probs = torch.nn.Softmax(dim=-1)(part_logits) 
    name = torch.argsort(probs, dim=-1, descending=True)[0][0].item()
    name = label_dict[name]    
    draw.text((i[0],i[1]-60),  str(name), font=ImageFont.truetype("screen/NanumGothicCoding-Regular.ttf", 45), fill=(0,255,0)) 
    draw.rectangle(i, outline=(0,255,0), width = 6)

# PIL 이미지 -> cv2 Mat 타입으로 변경
numpy_img = np.array(img_pil)
cv_img = cv2.cvtColor(numpy_img, cv2.COLOR_RGB2BGR) 
plt.imshow(cv_img) 
plt.savefig(f"{df_all[df_all['num']==picture_num]['path'][0].replace('/','_')}.png")
